# %%
import pandas as pd
import requests

# %% [markdown]
# #### FIFA World Cup 2022

# %%
competition_id = 43
season_id = 106

# %%
url = f"https://raw.githubusercontent.com/statsbomb/open-data/refs/heads/master/data/matches/{competition_id}/{season_id}.json"
data = requests.get(url).json()
matches = pd.json_normalize(data)
matches.head(2)
# Out:
#    match_id  match_date      kick_off  home_score  away_score match_status  \
# 0   3857276  2022-12-01  15:00:00.000           1           2    available
# 1   3857271  2022-11-21  13:00:00.000           6           2    available
#
#   match_status_360                last_updated            last_updated_360  \
# 0        available  2026-05-04T01:46:04.664252  2026-05-04T01:50:33.318123
# 1        available  2026-05-04T01:40:47.671394  2026-05-04T01:43:30.216315
#
#    match_week  ...  competition_stage.id competition_stage.name stadium.id  \
# 0           3  ...                    10            Group Stage    1000838
# 1           1  ...                    10            Group Stage    1000253
#
#                            stadium.name stadium.country.id  \
# 0                    Al Thumama Stadium                185
# 1  Sheikh Khalifa International Stadium                185
#
#    stadium.country.name referee.id   referee.name referee.country.id  \
# 0                 Qatar     2638.0  Raphael Claus               31.0
# 1                 Qatar     2638.0  Raphael Claus               31.0
#
#    referee.country.name
# 0                Brazil
# 1                Brazil
#
# [2 rows x 42 columns]

# %%
len(matches)
# Out:
# 64

# %%
for _, row in matches.head(2).iterrows():
    print(
        f"{row['home_team.home_team_name']} {row['away_team.away_team_name']} "
        f"{row['home_score']}:{row['away_score']} ({row['match_id']})"
    )
# Out:
# Canada Morocco 1:2 (3857276)
# England Iran 6:2 (3857271)
