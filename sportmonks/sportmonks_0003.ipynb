# %%
import os

import pandas as pd
import requests
from dotenv import load_dotenv

# %%
load_dotenv(".env")

API_TOKEN = os.getenv("API_TOKEN")

# %% [markdown]
# #### Fixtures (matches) by date range (max 100 days)

# %%
start_date = "2025-11-17"
end_date = "2025-11-17"

data = []
page = 1
has_more = True

while has_more:
    params = {"api_token": API_TOKEN, "per_page": 50, "page": page}
    r = requests.get(f"https://api.sportmonks.com/v3/football/fixtures/between/{start_date}/{end_date}", params=params).json()
    data.extend(r["data"])
    has_more = r["pagination"]["has_more"]
    page += 1

# %%
matches = pd.json_normalize(data)
matches.head(13)
# Out:
#          id  sport_id  league_id  season_id  stage_id  group_id aggregate_id  \
# 0  19345768         1        720      21887  77464842    249217         None
# 1  19345769         1        720      21887  77464842    251897         None
# 2  19427866         1        720      21887  77464842    249211         None
# 3  19427867         1        720      21887  77464842    249211         None
# 4  19427959         1        720      21887  77464842    249217         None
# 5  19427961         1        720      21887  77464842    251897         None
#
#    round_id  state_id  venue_id                            name  \
# 0    362711         5       974                 Malta vs Poland
# 1    362711         5      1810     Czech Republic vs Gibraltar
# 2    362711         5      3876             Germany vs Slovakia
# 3    362711         5      8014  Northern Ireland vs Luxembourg
# 4    362711         5       154        Netherlands vs Lithuania
# 5    362711         5      3600           Montenegro vs Croatia
#
#            starting_at                            result_info  leg details  \
# 0  2025-11-17 19:45:00            Poland won after full-time.  1/1    None
# 1  2025-11-17 19:45:00    Czech Republic won after full-time.  1/1    None
# 2  2025-11-17 19:45:00           Germany won after full-time.  1/1    None
# 3  2025-11-17 19:45:00  Northern Ireland won after full-time.  1/1    None
# 4  2025-11-17 19:45:00       Netherlands won after full-time.  1/1    None
# 5  2025-11-17 19:45:00           Croatia won after full-time.  1/1    None
#
#    length  placeholder  has_odds  has_premium_odds  starting_at_timestamp
# 0      90        False      True              True             1763408700
# 1      90        False      True              True             1763408700
# 2      90        False      True              True             1763408700
# 3      90        False      True              True             1763408700
# 4      90        False      True              True             1763408700
# 5      90        False      True              True             1763408700
