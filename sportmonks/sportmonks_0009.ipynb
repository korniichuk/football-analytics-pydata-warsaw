# %%
import os

import pandas as pd
import requests
from dotenv import load_dotenv

# %%
load_dotenv(".env")

API_TOKEN = os.getenv("API_TOKEN")
params = {"api_token": API_TOKEN, "include": "lineups.details.type"}

# %%
data = requests.get("https://api.sportmonks.com/v3/football/fixtures/19146817", params=params).json()["data"]
match = pd.json_normalize(data)

# %%
lineups = pd.json_normalize(match.lineups[0])
len(lineups)
# Out:
# 40

# %%
def head_skip_all_nan(df, n):
    return df.dropna(axis=1, how='all').head(n)
    
head_skip_all_nan(lineups.drop('details', axis=1), 5)
# Out:
#             id  sport_id  fixture_id  player_id  team_id  position_id  \
# 0  14597927439         1    19146817     123690      246         26.0
# 1  14597927412         1    19146817     580993      246         25.0
# 2  14597927435         1    19146817       9654      246         25.0
# 3  14597927126         1    19146817     174741      246          NaN
# 4  14597927130         1    19146817   34422813      246          NaN
#
#   formation_field  type_id  formation_position    player_name  jersey_number
# 0             3:5       11                 5.0    James Brown              2
# 1             2:1       11                 4.0        R. Leak              3
# 2             2:3       11                 2.0    Akil Wright              4
# 3            None       12                 NaN   S. Allardice              6
# 4            None       12                 NaN  Victor Loturi              7

# %%
lineups.to_pickle("lineups.pkl")
