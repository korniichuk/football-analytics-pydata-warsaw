# %%
import pandas as pd

# %%
lineups = pd.read_pickle("lineups.pkl")

# %%
exploded = lineups.explode('details').reset_index(drop=True)
normalized = pd.json_normalize(exploded["details"])
pd.concat([exploded.drop('details', axis=1), normalized[["data.value", "type.name"]]], axis=1)
# Out:
#               id  sport_id  fixture_id  player_id  team_id  position_id  \
# 0    14597927439         1    19146817     123690      246         26.0
# 1    14597927439         1    19146817     123690      246         26.0
# 2    14597927439         1    19146817     123690      246         26.0
# 3    14597927439         1    19146817     123690      246         26.0
# 4    14597927439         1    19146817     123690      246         26.0
# ..           ...       ...         ...        ...      ...          ...
# 922  14597927129         1    19146817   37344344      273         27.0
# 923  14597927129         1    19146817   37344344      273         27.0
# 924  14597927129         1    19146817   37344344      273         27.0
# 925  14597927129         1    19146817   37344344      273         27.0
# 926  14597927129         1    19146817   37344344      273         27.0
#
#     formation_field  type_id  formation_position    player_name  \
# 0               3:5       11                 5.0    James Brown
# 1               3:5       11                 5.0    James Brown
# 2               3:5       11                 5.0    James Brown
# 3               3:5       11                 5.0    James Brown
# 4               3:5       11                 5.0    James Brown
# ..              ...      ...                 ...            ...
# 922             4:3       11                10.0  Topi Keskinen
# 923             4:3       11                10.0  Topi Keskinen
# 924             4:3       11                10.0  Topi Keskinen
# 925             4:3       11                10.0  Topi Keskinen
# 926             4:3       11                10.0  Topi Keskinen
#
#      jersey_number data.value                   type.name
# 0                2         75  Accurate Passes Percentage
# 1                2          4                   Duels Won
# 2                2          2                 Fouls Drawn
# 3                2          6                 Total Duels
# 4                2         12             Accurate Passes
# ..             ...        ...                         ...
# 922             81          5                   Turn Over
# 923             81         22                      Passes
# 924             81          1                 Aerials Won
# 925             81          3             Chances Created
# 926             81        110   Cumulative Minutes Played
#
# [927 rows x 13 columns]
