# %%
import os

import pandas as pd
import requests
from dotenv import load_dotenv

# %%
load_dotenv(".env")

API_TOKEN = os.getenv("API_TOKEN")
params = {"api_token": API_TOKEN, "include": "statistics.type;events;formations;timeline;lineups.details.type"}

# %%
data = requests.get("https://api.sportmonks.com/v3/football/fixtures/19146817", params=params).json()["data"]
match = pd.json_normalize(data)
match.columns
# Out:
# Index(['id', 'sport_id', 'league_id', 'season_id', 'stage_id', 'group_id',
#        'aggregate_id', 'round_id', 'state_id', 'venue_id', 'name',
#        'starting_at', 'result_info', 'leg', 'details', 'length', 'placeholder',
#        'has_odds', 'has_premium_odds', 'starting_at_timestamp', 'statistics',
#        'events', 'formations', 'timeline', 'lineups'],
#       dtype='object')

# %%
statistics = pd.json_normalize(match.statistics[0])

# %%
statistics.head(5)
# Out:
#           id  fixture_id  type_id  participant_id location  data.value  \
# 0  207023010    19146817       34             246     away           4
# 1  207022998    19146817       34             273     home           9
# 2  207023272    19146817       45             246     away          34
# 3  207023271    19146817       45             273     home          66
# 4  207022992    19146817       52             246     away           2
#
#    type.id          type.name        type.code type.developer_name  \
# 0       34            Corners          corners             CORNERS
# 1       34            Corners          corners             CORNERS
# 2       45  Ball Possession %  ball-possession     BALL_POSSESSION
# 3       45  Ball Possession %  ball-possession     BALL_POSSESSION
# 4       52              Goals            goals               GOALS
#
#   type.model_type type.stat_group
# 0       statistic       offensive
# 1       statistic       offensive
# 2       statistic         overall
# 3       statistic         overall
# 4       statistic       offensive
